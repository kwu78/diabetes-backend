# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
pwd()
# Out:
# '/Users/yuesongyang/Desktop/diabetes-dashboard/data_processing/notebooks'

# %% [markdown]
# # Measures

# %%
measures = pd.read_csv("../inputs/2024_national_health_data_measures.csv")

# %%
list(measures.columns)
# Out:
# ['FIPS',
#  'State',
#  'County',
#  'Unreliable',
#  'Deaths',
#  'Years of Potential Life Lost Rate',
#  '95% CI - Low',
#  '95% CI - High',
#  'National Z-Score',
#  'YPLL Rate (Hispanic (all races))',
#  'YPLL Rate (Hispanic (all races)) 95% CI - Low',
#  'YPLL Rate (Hispanic (all races)) 95% CI - High',
#  'YPLL Rate (Hispanic (all races)) Unreliable',
#  'YPLL Rate (Non-Hispanic AIAN)',
#  'YPLL Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'YPLL Rate (Non-Hispanic AIAN) 95% CI - High',
#  'YPLL Rate (Non-Hispanic AIAN) Unreliable',
#  'YPLL Rate (Non-Hispanic Asian)',
#  'YPLL Rate (Non-Hispanic Asian) 95% CI - Low',
#  'YPLL Rate (Non-Hispanic Asian) 95% CI - High',
#  'YPLL Rate (Non-Hispanic Asian) Unreliable',
#  'YPLL Rate (Non-Hispanic Black)',
#  'YPLL Rate (Non-Hispanic Black) 95% CI - Low',
#  'YPLL Rate (Non-Hispanic Black) 95% CI - High',
#  'YPLL Rate (Non-Hispanic Black) Unreliable',
#  'YPLL Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'YPLL Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'YPLL Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'YPLL Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) Unreliable',
#  'YPLL Rate (Non-Hispanic 2+ races)',
#  'YPLL Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'YPLL Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'YPLL Rate (Non-Hispanic 2+ races) Unreliable',
#  'YPLL Rate (Non-Hispanic White)',
#  'YPLL Rate (Non-Hispanic White) 95% CI - Low',
#  'YPLL Rate (Non-Hispanic White) 95% CI - High',
#  'YPLL Rate (Non-Hispanic White) Unreliable',
#  '% Fair or Poor Health',
#  '95% CI - Low.1',
#  '95% CI - High.1',
#  'National Z-Score.1',
#  'Average Number of Physically Unhealthy Days',
#  '95% CI - Low.2',
#  '95% CI - High.2',
#  'National Z-Score.2',
#  'Average Number of Mentally Unhealthy Days',
#  '95% CI - Low.3',
#  '95% CI - High.3',
#  'National Z-Score.3',
#  'Unreliable.1',
#  '% Low Birthweight',
#  '95% CI - Low.4',
#  '95% CI - High.4',
#  'National Z-Score.4',
#  '% LBW (Hispanic (all races))',
#  '% LBW (Hispanic (all races)) 95% CI - Low',
#  '% LBW (Hispanic (all races)) 95% CI - High',
#  '% LBW (Non-Hispanic AIAN)',
#  '% LBW (Non-Hispanic AIAN) 95% CI - Low',
#  '% LBW (Non-Hispanic AIAN) 95% CI - High',
#  '% LBW (Non-Hispanic Asian)',
#  '% LBW (Non-Hispanic Asian) 95% CI - Low',
#  '% LBW (Non-Hispanic Asian) 95% CI - High',
#  '% LBW (Non-Hispanic Black)',
#  '% LBW (Non-Hispanic Black) 95% CI - Low',
#  '% LBW (Non-Hispanic Black) 95% CI - High',
#  '% LBW (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  '% LBW (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  '% LBW (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  '% LBW (Non-Hispanic 2+ races)',
#  '% LBW (Non-Hispanic 2+ races) 95% CI - Low',
#  '% LBW (Non-Hispanic 2+ races) 95% CI - High',
#  '% LBW (Non-Hispanic White)',
#  '% LBW (Non-Hispanic White) 95% CI - Low',
#  '% LBW (Non-Hispanic White) 95% CI - High',
#  '% Adults Reporting Currently Smoking',
#  '95% CI - Low.5',
#  '95% CI - High.5',
#  'National Z-Score.5',
#  '% Adults with Obesity',
#  '95% CI - Low.6',
#  '95% CI - High.6',
#  'National Z-Score.6',
#  'Food Environment Index',
#  'National Z-Score.7',
#  '% Physically Inactive',
#  '95% CI - Low.7',
#  '95% CI - High.7',
#  'National Z-Score.8',
#  '% With Access to Exercise Opportunities',
#  'National Z-Score.9',
#  '% Excessive Drinking',
#  '95% CI - Low.8',
#  '95% CI - High.8',
#  'National Z-Score.10',
#  '# Alcohol-Impaired Driving Deaths',
#  '# Driving Deaths',
#  '% Driving Deaths with Alcohol Involvement',
#  '95% CI - Low.9',
#  '95% CI - High.9',
#  'National Z-Score.11',
#  '# Chlamydia Cases',
#  'Chlamydia Rate',
#  'National Z-Score.12',
#  'Teen Birth Rate',
#  '95% CI - Low.10',
#  '95% CI - High.10',
#  'National Z-Score.13',
#  'Teen Birth Rate (Hispanic (all races))',
#  'Teen Birth Rate (Hispanic (all races)) 95% CI - Low',
#  'Teen Birth Rate (Hispanic (all races)) 95% CI - High',
#  'Teen Birth Rate (Non-Hispanic AIAN)',
#  'Teen Birth Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'Teen Birth Rate (Non-Hispanic AIAN) 95% CI - High',
#  'Teen Birth Rate (Non-Hispanic Asian)',
#  'Teen Birth Rate (Non-Hispanic Asian) 95% CI - Low',
#  'Teen Birth Rate (Non-Hispanic Asian) 95% CI - High',
#  'Teen Birth Rate (Non-Hispanic Black)',
#  'Teen Birth Rate (Non-Hispanic Black) 95% CI - Low',
#  'Teen Birth Rate (Non-Hispanic Black) 95% CI - High',
#  'Teen Birth Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Teen Birth Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Teen Birth Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Teen Birth Rate (Non-Hispanic 2+ races)',
#  'Teen Birth Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'Teen Birth Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'Teen Birth Rate (Non-Hispanic White)',
#  'Teen Birth Rate (Non-Hispanic White) 95% CI - Low',
#  'Teen Birth Rate (Non-Hispanic White) 95% CI - High',
#  '# Uninsured',
#  '% Uninsured',
#  '95% CI - Low.11',
#  '95% CI - High.11',
#  'National Z-Score.14',
#  '# Primary Care Physicians',
#  'Primary Care Physicians Rate',
#  'Primary Care Physicians Ratio',
#  'National Z-Score.15',
#  '# Dentists',
#  'Dentist Rate',
#  'Dentist Ratio',
#  'National Z-Score.16',
#  '# Mental Health Providers',
#  'Mental Health Provider Rate',
#  'Mental Health Provider Ratio',
#  'National Z-Score.17',
#  'Preventable Hospitalization Rate',
#  'National Z-Score.18',
#  'Preventable Hosp. Rate (AIAN)',
#  'Preventable Hosp. Rate (Asian)',
#  'Preventable Hosp. Rate (Black)',
#  'Preventable Hosp. Rate (Hispanic)',
#  'Preventable Hosp. Rate (White)',
#  '% with Annual Mammogram',
#  'National Z-Score.19',
#  '% Screened (AIAN)',
#  '% Screened (Asian)',
#  '% Screened (Black)',
#  '% Screened (Hispanic)',
#  '% Screened (White)',
#  '% Vaccinated',
#  'National Z-Score.20',
#  '% Vaccinated (AIAN)',
#  '% Vaccinated (Asian)',
#  '% Vaccinated (Black)',
#  '% Vaccinated (Hispanic)',
#  '% Vaccinated (White)',
#  '# Completed High School',
#  'Population',
#  '% Completed High School',
#  '95% CI - Low.12',
#  '95% CI - High.12',
#  'National Z-Score.21',
#  '# Some College',
#  'Population.1',
#  '% Some College',
#  '95% CI - Low.13',
#  '95% CI - High.13',
#  'National Z-Score.22',
#  '# Unemployed',
#  'Labor Force',
#  '% Unemployed',
#  'National Z-Score.23',
#  '% Children in Poverty',
#  '95% CI - Low.14',
#  '95% CI - High.14',
#  'National Z-Score.24',
#  '% Children in Poverty (AIAN)',
#  '% Children in Poverty (Asian)',
#  '% Children in Poverty (Black)',
#  '% Children in Poverty (Hispanic)',
#  '% Children in Poverty (White)',
#  '80th Percentile Income',
#  '20th Percentile Income',
#  'Income Ratio',
#  'National Z-Score.25',
#  '# Children in Single-Parent Households',
#  '# Children in Households',
#  '% Children in Single-Parent Households',
#  '95% CI - Low.15',
#  '95% CI - High.15',
#  'National Z-Score.26',
#  '# Associations',
#  'Social Association Rate',
#  'National Z-Score.27',
#  '# Injury Deaths',
#  'Injury Death Rate',
#  '95% CI - Low.16',
#  '95% CI - High.16',
#  'National Z-Score.28',
#  'Injury Death Rate (Hispanic (all races))',
#  'Injury Death Rate (Hispanic (all races)) 95% CI - Low',
#  'Injury Death Rate (Hispanic (all races)) 95% CI - High',
#  'Injury Death Rate (Non-Hispanic AIAN)',
#  'Injury Death Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'Injury Death Rate (Non-Hispanic AIAN) 95% CI - High',
#  'Injury Death Rate (Non-Hispanic Asian)',
#  'Injury Death Rate (Non-Hispanic Asian) 95% CI - Low',
#  'Injury Death Rate (Non-Hispanic Asian) 95% CI - High',
#  'Injury Death Rate (Non-Hispanic Black)',
#  'Injury Death Rate (Non-Hispanic Black) 95% CI - Low',
#  'Injury Death Rate (Non-Hispanic Black) 95% CI - High',
#  'Injury Death Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Injury Death Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Injury Death Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Injury Death Rate (Non-Hispanic 2+ races)',
#  'Injury Death Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'Injury Death Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'Injury Death Rate (Non-Hispanic White)',
#  'Injury Death Rate (Non-Hispanic White) 95% CI - Low',
#  'Injury Death Rate (Non-Hispanic White) 95% CI - High',
#  'Average Daily PM2.5',
#  'National Z-Score.29',
#  'Presence of Water Violation',
#  'National Z-Score.30',
#  '% Severe Housing Problems',
#  '95% CI - Low.17',
#  '95% CI - High.17',
#  'Severe Housing Cost Burden',
#  'Severe Housing Cost Burden 95% CI - Low',
#  'Severe Housing Cost Burden 95% CI - High',
#  'Overcrowding',
#  'Overcrowding 95% CI - Low',
#  'Overcrowding 95% CI - High',
#  'Inadequate Facilities',
#  'Inadequate Facilities 95% CI - Low',
#  'Inadequate Facilities 95% CI - High',
#  'National Z-Score.31',
#  '% Drive Alone to Work',
#  '95% CI - Low.18',
#  '95% CI - High.18',
#  'National Z-Score.32',
#  '% Drive Alone (AIAN)',
#  '% Drive Alone (AIAN) 95% CI - Low',
#  '% Drive Alone (AIAN) 95% CI - High',
#  '% Drive Alone (Asian)',
#  '% Drive Alone (Asian) 95% CI - Low',
#  '% Drive Alone (Asian) 95% CI - High',
#  '% Drive Alone (Black)',
#  '% Drive Alone (Black) 95% CI - Low',
#  '% Drive Alone (Black) 95% CI - High',
#  '% Drive Alone (Hispanic)',
#  '% Drive Alone (Hispanic) 95% CI - Low',
#  '% Drive Alone (Hispanic) 95% CI - High',
#  '% Drive Alone (White)',
#  '% Drive Alone (White) 95% CI - Low',
#  '% Drive Alone (White) 95% CI - High',
#  '# Workers who Drive Alone',
#  '% Long Commute - Drives Alone',
#  '95% CI - Low.19',
#  '95% CI - High.19',
#  'National Z-Score.33']

# %%
display_measures = ["State", 
                    "County", 
                    "FIPS", 
                    "% Adults with Obesity", 
                    "% Adults Reporting Currently Smoking",
                    "% Physically Inactive",
                    "% Excessive Drinking",
                    #"Average Number of Mentally Unhealthy Days"
                   ]
mapped_display_measures = ["STATE_NAME",
                           "COUNTY_NAME",
                           "FIPS",
                           "Obesity",
                           "Adult Smoking",
                           "Physical Inactivity",
                           "Excessive Drinking",
                          ]

# %%
dislay_df_measures = measures[display_measures]

# %%
dislay_df_measures.rename(columns = {k : v for k,v in zip(display_measures, mapped_display_measures)},
                          inplace = True
                         )

# %%
dislay_df_measures.head()
# Out:
#   STATE_NAME COUNTY_NAME  FIPS  Obesity  Adult Smoking  Physical Inactivity  \
# 0    Alabama         NaN  1000     41.0           18.0                 30.0
# 1    Alabama     Autauga  1001     39.0           17.0                 29.0
# 2    Alabama     Baldwin  1003     37.0           15.0                 28.0
# 3    Alabama     Barbour  1005     43.0           25.0                 40.0
# 4    Alabama        Bibb  1007     40.0           22.0                 36.0
#
#    Excessive Drinking
# 0                14.0
# 1                15.0
# 2                16.0
# 3                12.0
# 4                15.0

# %%
dislay_df_measures.isna().sum()
# Out:
# STATE_NAME              0
# COUNTY_NAME            51
# FIPS                    0
# Obesity                 7
# Adult Smoking           7
# Physical Inactivity     7
# Excessive Drinking      7
# dtype: int64

# %%
dislay_df_measures['Obesity'] = dislay_df_measures['Obesity'].fillna(-1)
dislay_df_measures['Adult Smoking'] = dislay_df_measures['Adult Smoking'].fillna(-1)
dislay_df_measures['Physical Inactivity'] = dislay_df_measures['Physical Inactivity'].fillna(-1)
dislay_df_measures['Excessive Drinking'] = dislay_df_measures['Excessive Drinking'].fillna(-1)

# %%
dislay_df_measures.isna().sum()
# Out:
# STATE_NAME              0
# COUNTY_NAME            51
# FIPS                    0
# Obesity                 0
# Adult Smoking           0
# Physical Inactivity     0
# Excessive Drinking      0
# dtype: int64

# %% [markdown]
# # Additional Measures

# %%
additional_measures = pd.read_csv("../inputs/2024_national_health_data_additional_measures.csv")

# %%
list(additional_measures.columns)
# Out:
# ['FIPS',
#  'State',
#  'County',
#  'Life Expectancy',
#  '95% CI - Low',
#  '95% CI - High',
#  'Life Expectancy (Hispanic (all races))',
#  'Life Expectancy (Hispanic (all races)) 95% CI - Low',
#  'Life Expectancy (Hispanic (all races)) 95% CI - High',
#  'Life Expectancy (Non-Hispanic AIAN)',
#  'Life Expectancy (Non-Hispanic AIAN) 95% CI - Low',
#  'Life Expectancy (Non-Hispanic AIAN) 95% CI - High',
#  'Life Expectancy (Non-Hispanic Asian)',
#  'Life Expectancy (Non-Hispanic Asian) 95% CI - Low',
#  'Life Expectancy (Non-Hispanic Asian) 95% CI - High',
#  'Life Expectancy (Non-Hispanic Black)',
#  'Life Expectancy (Non-Hispanic Black) 95% CI - Low',
#  'Life Expectancy (Non-Hispanic Black) 95% CI - High',
#  'Life Expectancy (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Life Expectancy (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Life Expectancy (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Life Expectancy (Non-Hispanic 2+ races)',
#  'Life Expectancy (Non-Hispanic 2+ races) 95% CI - Low',
#  'Life Expectancy (Non-Hispanic 2+ races) 95% CI - High',
#  'Life Expectancy (Non-Hispanic White)',
#  'Life Expectancy (Non-Hispanic White) 95% CI - Low',
#  'Life Expectancy (Non-Hispanic White) 95% CI - High',
#  '# Deaths',
#  'Age-Adjusted Death Rate',
#  '95% CI - Low.1',
#  '95% CI - High.1',
#  'Age-Adjusted Mortality (Hispanic (all races))',
#  'Age-Adjusted Mortality (Hispanic (all races)) 95% CI - Low',
#  'Age-Adjusted Mortality (Hispanic (all races)) 95% CI - High',
#  'Age-Adjusted Mortality (Non-Hispanic AIAN)',
#  'Age-Adjusted Mortality (Non-Hispanic AIAN) 95% CI - Low',
#  'Age-Adjusted Mortality (Non-Hispanic AIAN) 95% CI - High',
#  'Age-Adjusted Mortality (Non-Hispanic Asian)',
#  'Age-Adjusted Mortality (Non-Hispanic Asian) 95% CI - Low',
#  'Age-Adjusted Mortality (Non-Hispanic Asian) 95% CI - High',
#  'Age-Adjusted Mortality (Non-Hispanic Black)',
#  'Age-Adjusted Mortality (Non-Hispanic Black) 95% CI - Low',
#  'Age-Adjusted Mortality (Non-Hispanic Black) 95% CI - High',
#  'Age-Adjusted Mortality (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Age-Adjusted Mortality (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Age-Adjusted Mortality (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Age-Adjusted Mortality (Non-Hispanic 2+ races)',
#  'Age-Adjusted Mortality (Non-Hispanic 2+ races) 95% CI - Low',
#  'Age-Adjusted Mortality (Non-Hispanic 2+ races) 95% CI - High',
#  'Age-Adjusted Mortality (Non-Hispanic White)',
#  'Age-Adjusted Mortality (Non-Hispanic White) 95% CI - Low',
#  'Age-Adjusted Mortality (Non-Hispanic White) 95% CI - High',
#  '# Deaths.1',
#  'Child Mortality Rate',
#  '95% CI - Low.2',
#  '95% CI - High.2',
#  'Child Mortality Rate (Hispanic (all races))',
#  'Child Mortality Rate (Hispanic (all races)) 95% CI - Low',
#  'Child Mortality Rate (Hispanic (all races)) 95% CI - High',
#  'Child Mortality Rate (Non-Hispanic AIAN)',
#  'Child Mortality Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'Child Mortality Rate (Non-Hispanic AIAN) 95% CI - High',
#  'Child Mortality Rate (Non-Hispanic Asian)',
#  'Child Mortality Rate (Non-Hispanic Asian) 95% CI - Low',
#  'Child Mortality Rate (Non-Hispanic Asian) 95% CI - High',
#  'Child Mortality Rate (Non-Hispanic Black)',
#  'Child Mortality Rate (Non-Hispanic Black) 95% CI - Low',
#  'Child Mortality Rate (Non-Hispanic Black) 95% CI - High',
#  'Child Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Child Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Child Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Child Mortality Rate (Non-Hispanic 2+ races)',
#  'Child Mortality Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'Child Mortality Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'Child Mortality Rate (Non-Hispanic White)',
#  'Child Mortality Rate (Non-Hispanic White) 95% CI - Low',
#  'Child Mortality Rate (Non-Hispanic White) 95% CI - High',
#  '# Deaths.2',
#  'Infant Mortality Rate',
#  '95% CI - Low.3',
#  '95% CI - High.3',
#  'Infant Mortality Rate (Hispanic (all races))',
#  'Infant Mortality Rate (Hispanic (all races)) 95% CI - Low',
#  'Infant Mortality Rate (Hispanic (all races)) 95% CI - High',
#  'Infant Mortality Rate (Non-Hispanic AIAN)',
#  'Infant Mortality Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'Infant Mortality Rate (Non-Hispanic AIAN) 95% CI - High',
#  'Infant Mortality Rate (Non-Hispanic Asian)',
#  'Infant Mortality Rate (Non-Hispanic Asian) 95% CI - Low',
#  'Infant Mortality Rate (Non-Hispanic Asian) 95% CI - High',
#  'Infant Mortality Rate (Non-Hispanic Black)',
#  'Infant Mortality Rate (Non-Hispanic Black) 95% CI - Low',
#  'Infant Mortality Rate (Non-Hispanic Black) 95% CI - High',
#  'Infant Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Infant Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Infant Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Infant Mortality Rate (Non-Hispanic 2+ races)',
#  'Infant Mortality Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'Infant Mortality Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'Infant Mortality Rate (Non-Hispanic White)',
#  'Infant Mortality Rate (Non-Hispanic White) 95% CI - Low',
#  'Infant Mortality Rate (Non-Hispanic White) 95% CI - High',
#  '% Frequent Physical Distress',
#  '95% CI - Low.4',
#  '95% CI - High.4',
#  '% Frequent Mental Distress',
#  '95% CI - Low.5',
#  '95% CI - High.5',
#  '% Adults with Diabetes',
#  '95% CI - Low.6',
#  '95% CI - High.6',
#  '# HIV Cases',
#  'HIV Prevalence Rate',
#  '# Food Insecure',
#  '% Food Insecure',
#  '# Limited Access to Healthy Foods',
#  '% Limited Access to Healthy Foods',
#  '# Drug Overdose Deaths',
#  'Drug Overdose Mortality Rate',
#  '95% CI - Low.7',
#  '95% CI - High.7',
#  'Drug Overdose Mortality Rate (Hispanic (all races))',
#  'Drug Overdose Mortality Rate (Hispanic (all races)) 95% CI - Low',
#  'Drug Overdose Mortality Rate (Hispanic (all races)) 95% CI - High',
#  'Drug Overdose Mortality Rate (Non-Hispanic AIAN)',
#  'Drug Overdose Mortality Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'Drug Overdose Mortality Rate (Non-Hispanic AIAN) 95% CI - High',
#  'Drug Overdose Mortality Rate (Non-Hispanic Asian)',
#  'Drug Overdose Mortality Rate (Non-Hispanic Asian) 95% CI - Low',
#  'Drug Overdose Mortality Rate (Non-Hispanic Asian) 95% CI - High',
#  'Drug Overdose Mortality Rate (Non-Hispanic Black)',
#  'Drug Overdose Mortality Rate (Non-Hispanic Black) 95% CI - Low',
#  'Drug Overdose Mortality Rate (Non-Hispanic Black) 95% CI - High',
#  'Drug Overdose Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Drug Overdose Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Drug Overdose Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Drug Overdose Mortality Rate (Non-Hispanic 2+ races)',
#  'Drug Overdose Mortality Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'Drug Overdose Mortality Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'Drug Overdose Mortality Rate (Non-Hispanic White)',
#  'Drug Overdose Mortality Rate (Non-Hispanic White) 95% CI - Low',
#  'Drug Overdose Mortality Rate (Non-Hispanic White) 95% CI - High',
#  '% Insufficient Sleep',
#  '95% CI - Low.8',
#  '95% CI - High.8',
#  '# Uninsured Adults',
#  '% Uninsured Adults',
#  '95% CI - Low.9',
#  '95% CI - High.9',
#  '# Uninsured Children',
#  '% Uninsured Children',
#  '95% CI - Low.10',
#  '95% CI - High.10',
#  'Other Primary Care Provider Rate',
#  'Other Primary Care Provider Ratio',
#  'Cohort Size',
#  'High School Graduation Rate',
#  '% Disconnected Youth',
#  '95% CI - Low.11',
#  '95% CI - High.11',
#  'Average Grade Performance',
#  'Average Grade Performance (AIAN)',
#  'Average Grade Performance (Asian)',
#  'Average Grade Performance (Black)',
#  'Average Grade Performance (Hispanic)',
#  'Average Grade Performance (White)',
#  'Average Grade Performance.1',
#  'Average Grade Performance (AIAN).1',
#  'Average Grade Performance (Asian).1',
#  'Average Grade Performance (Black).1',
#  'Average Grade Performance (Hispanic).1',
#  'Average Grade Performance (White).1',
#  'Segregation Index',
#  'Spending per Pupil',
#  'School Funding Adequacy',
#  "Women's Median Earnings",
#  "Men's Median Earnings",
#  'Gender Pay Gap',
#  '95% CI - Low.12',
#  '95% CI - High.12',
#  'Median Household Income',
#  '95% CI - Low.13',
#  '95% CI - High.13',
#  'Household Income (AIAN)',
#  'Household Income (AIAN) 95% CI - Low',
#  'Household Income (AIAN) 95% CI - High',
#  'Household Income (Asian)',
#  'Household Income (Asian) 95% CI - Low',
#  'Household Income (Asian) 95% CI - High',
#  'Household Income (Black)',
#  'Household Income (Black) 95% CI - Low',
#  'Household Income (Black) 95% CI - High',
#  'Household Income (Hispanic)',
#  'Household Income (Hispanic) 95% CI - Low',
#  'Household Income (Hispanic) 95% CI - High',
#  'Household Income (White)',
#  'Household Income (White) 95% CI - Low',
#  'Household Income (White) 95% CI - High',
#  '% Enrolled in Free or Reduced Lunch',
#  'Segregation Index.1',
#  '% Household Income Required for Child Care Expenses',
#  '# Child Care Centers',
#  'Child Care Centers per 1,000 Children',
#  'Homicide Rate',
#  '95% CI - Low.14',
#  '95% CI - High.14',
#  'Homicide Rate (Hispanic (all races))',
#  'Homicide Rate (Hispanic (all races)) 95% CI - Low',
#  'Homicide Rate (Hispanic (all races)) 95% CI - High',
#  'Homicide Rate (Non-Hispanic AIAN)',
#  'Homicide Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'Homicide Rate (Non-Hispanic AIAN) 95% CI - High',
#  'Homicide Rate (Non-Hispanic Asian)',
#  'Homicide Rate (Non-Hispanic Asian) 95% CI - Low',
#  'Homicide Rate (Non-Hispanic Asian) 95% CI - High',
#  'Homicide Rate (Non-Hispanic Black)',
#  'Homicide Rate (Non-Hispanic Black) 95% CI - Low',
#  'Homicide Rate (Non-Hispanic Black) 95% CI - High',
#  'Homicide Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Homicide Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Homicide Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Homicide Rate (Non-Hispanic 2+ races)',
#  'Homicide Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'Homicide Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'Homicide Rate (Non-Hispanic White)',
#  'Homicide Rate (Non-Hispanic White) 95% CI - Low',
#  'Homicide Rate (Non-Hispanic White) 95% CI - High',
#  '# Deaths.3',
#  'Suicide Rate (Age-Adjusted)',
#  '95% CI - Low.15',
#  '95% CI - High.15',
#  'Crude Rate',
#  'Suicide Rate (Hispanic (all races))',
#  'Suicide Rate (Hispanic (all races)) 95% CI - Low',
#  'Suicide Rate (Hispanic (all races)) 95% CI - High',
#  'Suicide Rate (Non-Hispanic AIAN)',
#  'Suicide Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'Suicide Rate (Non-Hispanic AIAN) 95% CI - High',
#  'Suicide Rate (Non-Hispanic Asian)',
#  'Suicide Rate (Non-Hispanic Asian) 95% CI - Low',
#  'Suicide Rate (Non-Hispanic Asian) 95% CI - High',
#  'Suicide Rate (Non-Hispanic Black)',
#  'Suicide Rate (Non-Hispanic Black) 95% CI - Low',
#  'Suicide Rate (Non-Hispanic Black) 95% CI - High',
#  'Suicide Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Suicide Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Suicide Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Suicide Rate (Non-Hispanic 2+ races)',
#  'Suicide Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'Suicide Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'Suicide Rate (Non-Hispanic White)',
#  'Suicide Rate (Non-Hispanic White) 95% CI - Low',
#  'Suicide Rate (Non-Hispanic White) 95% CI - High',
#  '# Firearm Fatalities',
#  'Firearm Fatalities Rate',
#  '95% CI - Low.16',
#  '95% CI - High.16',
#  'Firearm Fatalities Rate (Hispanic (all races))',
#  'Firearm Fatalities Rate (Hispanic (all races)) 95% CI - Low',
#  'Firearm Fatalities Rate (Hispanic (all races)) 95% CI - High',
#  'Firearm Fatalities Rate (Non-Hispanic AIAN)',
#  'Firearm Fatalities Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'Firearm Fatalities Rate (Non-Hispanic AIAN) 95% CI - High',
#  'Firearm Fatalities Rate (Non-Hispanic Asian)',
#  'Firearm Fatalities Rate (Non-Hispanic Asian) 95% CI - Low',
#  'Firearm Fatalities Rate (Non-Hispanic Asian) 95% CI - High',
#  'Firearm Fatalities Rate (Non-Hispanic Black)',
#  'Firearm Fatalities Rate (Non-Hispanic Black) 95% CI - Low',
#  'Firearm Fatalities Rate (Non-Hispanic Black) 95% CI - High',
#  'Firearm Fatalities Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'Firearm Fatalities Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'Firearm Fatalities Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'Firearm Fatalities Rate (Non-Hispanic 2+ races)',
#  'Firearm Fatalities Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'Firearm Fatalities Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'Firearm Fatalities Rate (Non-Hispanic White)',
#  'Firearm Fatalities Rate (Non-Hispanic White) 95% CI - Low',
#  'Firearm Fatalities Rate (Non-Hispanic White) 95% CI - High',
#  '# Motor Vehicle Deaths',
#  'Motor Vehicle Mortality Rate',
#  '95% CI - Low.17',
#  '95% CI - High.17',
#  'MV Mortality Rate (Hispanic (all races))',
#  'MV Mortality Rate (Hispanic (all races)) 95% CI - Low',
#  'MV Mortality Rate (Hispanic (all races)) 95% CI - High',
#  'MV Mortality Rate (Non-Hispanic AIAN)',
#  'MV Mortality Rate (Non-Hispanic AIAN) 95% CI - Low',
#  'MV Mortality Rate (Non-Hispanic AIAN) 95% CI - High',
#  'MV Mortality Rate (Non-Hispanic Asian)',
#  'MV Mortality Rate (Non-Hispanic Asian) 95% CI - Low',
#  'MV Mortality Rate (Non-Hispanic Asian) 95% CI - High',
#  'MV Mortality Rate (Non-Hispanic Black)',
#  'MV Mortality Rate (Non-Hispanic Black) 95% CI - Low',
#  'MV Mortality Rate (Non-Hispanic Black) 95% CI - High',
#  'MV Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander)',
#  'MV Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - Low',
#  'MV Mortality Rate (Non-Hispanic Native Hawaiian and Other Pacific Islander) 95% CI - High',
#  'MV Mortality Rate (Non-Hispanic 2+ races)',
#  'MV Mortality Rate (Non-Hispanic 2+ races) 95% CI - Low',
#  'MV Mortality Rate (Non-Hispanic 2+ races) 95% CI - High',
#  'MV Mortality Rate (Non-Hispanic White)',
#  'MV Mortality Rate (Non-Hispanic White) 95% CI - Low',
#  'MV Mortality Rate (Non-Hispanic White) 95% CI - High',
#  'Non-Petitioned Cases',
#  'Petitioned Cases',
#  'Denominator',
#  'Juvenile Arrest Rate',
#  '% Voter Turnout',
#  '% Census Participation',
#  'Traffic Volume',
#  '# Homeowners',
#  '% Homeowners',
#  '95% CI - Low.18',
#  '95% CI - High.18',
#  '# Households with Severe Cost Burden',
#  '% Households with Severe Cost Burden',
#  '95% CI - Low.19',
#  '95% CI - High.19',
#  '% Households with Broadband Access',
#  '# Households with Broadband Access',
#  '95% CI - Low.20',
#  '95% CI - High.20',
#  'Population',
#  '% Less than 18 Years of Age',
#  '% 65 and Over',
#  '# Black',
#  '% Black',
#  '# American Indian or Alaska Native',
#  '% American Indian or Alaska Native',
#  '# Asian',
#  '% Asian',
#  '# Native Hawaiian or Other Pacific Islander',
#  '% Native Hawaiian or Other Pacific Islander',
#  '# Hispanic',
#  '% Hispanic',
#  '# Non-Hispanic White',
#  '% Non-Hispanic White',
#  '# Not Proficient in English',
#  '% Not Proficient in English',
#  '95% CI - Low.21',
#  '95% CI - High.21',
#  '% Female',
#  '# Rural Residents',
#  '% Rural']

# %%
display_additional_measures = ["State",
                               "County",
                               "FIPS",
                               "% Frequent Mental Distress",
                               "% Adults with Diabetes",
                              ]

mapped_display_additional_measures = ["STATE_NAME",
                                       "COUNTY_NAME",
                                       "FIPS",
                                       "Poor Mental Health",
                                       "Diabetes",
                                      ]

# %%
dislay_df_additional_measures = additional_measures[display_additional_measures]

# %%
dislay_df_additional_measures.rename(columns = {k : v for k,v in zip(display_additional_measures, 
                                                                     mapped_display_additional_measures)},
                                     inplace = True
                                    )

# %%
dislay_df_additional_measures.isna().sum()
# Out:
# STATE_NAME             0
# COUNTY_NAME           51
# FIPS                   0
# Poor Mental Health     7
# Diabetes               7
# dtype: int64

# %%
dislay_df_additional_measures.head()
# Out:
#   STATE_NAME COUNTY_NAME  FIPS  Poor Mental Health  Diabetes
# 0    Alabama         NaN  1000                20.0      13.0
# 1    Alabama     Autauga  1001                18.0      11.0
# 2    Alabama     Baldwin  1003                17.0      10.0
# 3    Alabama     Barbour  1005                21.0      16.0
# 4    Alabama        Bibb  1007                19.0      12.0

# %%
dislay_df_additional_measures['Poor Mental Health'] = dislay_df_additional_measures['Poor Mental Health'].fillna(-1)
dislay_df_additional_measures['Diabetes'] = dislay_df_additional_measures['Diabetes'].fillna(-1)

# %%
dislay_df_additional_measures.isna().sum()
# Out:
# STATE_NAME             0
# COUNTY_NAME           51
# FIPS                   0
# Poor Mental Health     0
# Diabetes               0
# dtype: int64

# %% [markdown]
# # Merge

# %%
len(dislay_df_measures)
# Out:
# 3201

# %%
len(dislay_df_additional_measures)
# Out:
# 3201

# %%
merged = dislay_df_measures.merge(dislay_df_additional_measures,
                                 on = ["STATE_NAME", "COUNTY_NAME", "FIPS"],
                                 how = "inner"
                                )

# %%
len(merged)
# Out:
# 3201

# %%
merged.head()
# Out:
#   STATE_NAME COUNTY_NAME  FIPS  Obesity  Adult Smoking  Physical Inactivity  \
# 0    Alabama         NaN  1000     41.0           18.0                 30.0
# 1    Alabama     Autauga  1001     39.0           17.0                 29.0
# 2    Alabama     Baldwin  1003     37.0           15.0                 28.0
# 3    Alabama     Barbour  1005     43.0           25.0                 40.0
# 4    Alabama        Bibb  1007     40.0           22.0                 36.0
#
#    Excessive Drinking  Poor Mental Health  Diabetes
# 0                14.0                20.0      13.0
# 1                15.0                18.0      11.0
# 2                16.0                17.0      10.0
# 3                12.0                21.0      16.0
# 4                15.0                19.0      12.0

# %% [markdown]
# # CSV

# %%
merged.to_csv("../outputs/2024_national_health.csv")

# %% [markdown]
# # County Json

# %%
county = merged[~merged['COUNTY_NAME'].isna()]

# %%
len(county)
# Out:
# 3150

# %%
county_json = county.to_json("../outputs/county_json.json", orient="records")

# %% [markdown]
# State Json

# %%
state = merged[merged['COUNTY_NAME'].isna()]

# %%
len(state)
# Out:
# 51

# %%
state.drop(['COUNTY_NAME'], axis = 1, inplace = True)

# %%
state.head()
# Out:
#      STATE_NAME  FIPS  Obesity  Adult Smoking  Physical Inactivity  \
# 0       Alabama  1000     41.0           18.0                 30.0
# 68       Alaska  2000     33.0           17.0                 20.0
# 104     Arizona  4000     32.0           14.0                 22.0
# 120    Arkansas  5000     39.0           22.0                 30.0
# 196  California  6000     28.0            9.0                 20.0
#
#      Excessive Drinking  Poor Mental Health  Diabetes
# 0                  14.0                20.0      13.0
# 68                 20.0                14.0       8.0
# 104                19.0                16.0      10.0
# 120                15.0                19.0      11.0
# 196                17.0                15.0      11.0

# %%
state_json = state.to_json("../outputs/state_json.json", orient="records")
